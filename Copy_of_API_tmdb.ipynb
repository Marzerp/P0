# %% [markdown]
# <a href="https://colab.research.google.com/github/Marzerp/P0/blob/main/Copy_of_API_tmdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.1.31)

# %%
import requests
import pandas as pd

# %%
# Tu clave API de TMDb
api_key = '95edfc7ed42b08b1ea975bdea765bc7b'

# URL de la API
url = f'https://api.themoviedb.org/3/trending/movie/week?api_key={api_key}&language=es-MX'

# Realizar la solicitud GET
response = requests.get(url)

data = response.json()

# %%
#Diccionario con los ids y generos de peliculas
genres_url = f'https://api.themoviedb.org/3/genre/movie/list?api_key={api_key}&language=es-MX'
genres_response = requests.get(genres_url)
genres_data = genres_response.json()
genres_dict = {genre['id']: genre['name'] for genre in genres_data['genres']}


movies_list = []
# Iterar sobre los resultados y almacenar los datos en la lista
for movie in data['results']:
        title = movie['title']
        release_date = movie['release_date']
        vote_average = movie['vote_average']
        genre_ids = movie['genre_ids']
        generos=  ', '.join([genres_dict.get(genre_id, 'Desconocido') for genre_id in genre_ids])

        # Añadir los datos de la película como un diccionario a la lista
        movies_list.append({
            'Título': title,
            'Fecha de estreno': release_date,
            'Puntuación promedio': vote_average,
            'Genero': generos
        })

# Crear un DataFrame de pandas con la lista de películas
df = pd.DataFrame(movies_list).sort_values(by='Puntuación promedio', ascending=False)

# %%
df
# Out:
#                               Título Fecha de estreno  Puntuación promedio  \
# 18                           哪吒之魔童闹海       2025-01-29                7.900
# 11                    Aún estoy aquí       2024-09-19                7.900
# 0                  El abismo secreto       2025-02-13                7.800
# 13          Las aventuras de Dog Man       2025-01-24                7.600
# 9                 Culpa Mía: Londres       2025-02-12                7.500
# 1                Mufasa: El rey león       2024-12-18                7.465
# 14                           Moana 2       2024-11-21                7.200
# 8                       La sustancia       2024-09-07                7.100
# 19                             Anora       2024-10-14                7.047
# 2                      El brutalista       2024-12-20                7.021
# 6                       Septiembre 5       2024-11-07                7.007
# 4                 Compañera perfecta       2025-01-22                7.000
# 7   Paddington: Aventura en la selva       2024-11-08                6.900
# 17                            Wicked       2024-11-20                6.900
# 10        Bridget Jones: Loca por él       2025-02-12                6.800
# 12                         Nosferatu       2024-12-25                6.700
# 15                     La dolce casa       2025-02-12                6.400
# 3    Capitán América: Un nuevo mundo       2025-02-12                6.200
# 5                 Amenaza en el aire       2025-01-22                5.700
# 16                         Mickey 17       2025-02-28                0.000
#
#                                         Genero
# 18               Animación, Fantasía, Aventura
# 11                             Drama, Historia
# 0           Romance, Ciencia ficción, Suspense
# 13         Familia, Animación, Comedia, Acción
# 9                               Romance, Drama
# 1                 Aventura, Familia, Animación
# 14       Animación, Aventura, Familia, Comedia
# 8                      Terror, Ciencia ficción
# 19                     Drama, Comedia, Romance
# 2                                        Drama
# 6                    Suspense, Drama, Historia
# 4   Terror, Ciencia ficción, Suspense, Comedia
# 7                   Familia, Aventura, Comedia
# 17                    Drama, Romance, Fantasía
# 10                     Comedia, Drama, Romance
# 12                            Terror, Fantasía
# 15                            Romance, Comedia
# 3            Acción, Suspense, Ciencia ficción
# 5                     Acción, Suspense, Crimen
# 16             Ciencia ficción, Comedia, Drama
